# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', 50)

# %%
role_models = pd.read_csv('../data/role_models_3.csv')

# %%
role_models.shape
# Out:
# (6966, 30)

# %%
role_models.columns
# Out:
# Index(['csd_10', 'gold_d_10', 'xpd_10', 'dmg_share', 'dmg_taken_share',
#        'vision_score', 'kill_participation', 'obj_dmg_share', 'dragons',
#        'barons', 'wards_cleared', 'vision_wards_purchased', 'kda_early',
#        'kda_mid', 'kda_late', 'solo_kills', 'teamfight_kills',
#        'skirmish_kills', 'wards_early', 'wards_mid', 'wards_late',
#        'summoner_id', 'most_played_champ', 'most_played_role',
#        'most_played_lane', 'region', 'player_name', 'op_gg',
#        'most_played_champ_name', 'role'],
#       dtype='object')

# %%
james = pd.read_csv('../data/morgan_test.csv')

# %%
X.columns
# Out:
# Index(['csd_10', 'gold_d_10', 'xpd_10', 'dmg_share', 'dmg_taken_share',
#        'vision_score', 'kill_participation', 'obj_dmg_share', 'dragons',
#        'barons', 'wards_cleared', 'vision_wards_purchased', 'kda_early',
#        'kda_mid', 'kda_late', 'solo_kills', 'teamfight_kills',
#        'skirmish_kills', 'wards_early', 'wards_mid', 'wards_late'],
#       dtype='object')

# %%
james.columns
# Out:
# Index(['csd_10', 'gold_d_10', 'xpd_10', 'dmg_share', 'dmg_taken_share',
#        'vision_score', 'kill_participation', 'obj_dmg_share', 'dragons',
#        'barons', 'wards_cleared', 'vision_wards_purchased', 'kda_early',
#        'kda_mid', 'kda_late', 'solo_kills', 'teamfight_kills',
#        'skirmish_kills', 'wards_early', 'wards_mid', 'wards_late',
#        'summoner_id', 'most_played_champ', 'most_played_role',
#        'most_played_lane', 'region', 'player_name'],
#       dtype='object')

# %%
X = role_models.drop(columns=['summoner_id','most_played_champ','most_played_role','most_played_lane','region','player_name'])
y = james.drop(columns = ['summoner_id','most_played_champ','most_played_role','most_played_lane','region','player_name'])

# %%
james
# Out:
#      csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0  5.643678  264.174713  310.172414     0.2146         0.155079      17.83908
#
#    kill_participation  obj_dmg_share   dragons    barons  wards_cleared  \
# 0             0.44436       0.221058  0.409086  0.164751       0.190992
#
#    vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# 0                0.158742   0.160558  0.375789  0.397365    0.079227
#
#    teamfight_kills  skirmish_kills  wards_early  wards_mid  wards_late  \
# 0         0.369459        0.287378     0.237528   0.361634    0.257208
#
#                                        summoner_id  most_played_champ  \
# 0  NmMlQYyDZuTiCKPfMtsMyEOWz0YB0jHvxLpIjH_p_-n1v7g                 22
#
#   most_played_role most_played_lane region    player_name
# 0        DUO_CARRY           BOTTOM     na  yamino hikari

# %%
ss = StandardScaler()
X_sc = ss.fit_transform(X)
y_sc = ss.transform(y)

X_sc = pd.DataFrame(X_sc, columns = X.columns)
y_sc = pd.DataFrame(y_sc, columns = X.columns)

# %%
diff_df = X_sc - y_sc.iloc[0,:]
norm_df = diff_df.apply(np.linalg.norm, ord=2, axis=1)

# %%
norm_df.sort_values()
# Out:
# 154      1.881788
# 2258     2.160382
# 1583     2.177751
# 1870     2.282485
# 225      2.338535
#           ...
# 5344    12.632816
# 5247    12.706460
# 5161    13.233640
# 6780    13.818424
# 6922    13.890090
# Length: 6966, dtype: float64

# %%
role_models['jr_similarity'] = norm_df

# %%
# Out:
# {'csd_10': 0    0.509677
#  Name: csd_10, dtype: float64,
#  'gold_d_10': 0    292.354839
#  Name: gold_d_10, dtype: float64,
#  'xpd_10': 0    334.794624
#  Name: xpd_10, dtype: float64,
#  'dmg_share': 0    0.182752
#  Name: dmg_share, dtype: float64,
#  'dmg_taken_share': 0    0.228005
#  Name: dmg_taken_share, dtype: float64,
#  'vision_score': 0    40.032258
#  Name: vision_score, dtype: float64,
#  'kill_participation': 0    0.505541
#  Name: kill_participation, dtype: float64,
#  'obj_dmg_share': 0    0.454272
#  Name: obj_dmg_share, dtype: float64,
#  'dragons': 0    0.433269
#  Name: dragons, dtype: float64,
#  'barons': 0    0.195341
#  Name: barons, dtype: float64,
#  'wards_cleared': 0    0.396977
#  Name: wards_cleared, dtype: float64,
#  'vision_wards_purchased': 0    0.323983
#  Name: vision_wards_purchased, dtype: float64,
#  'kda_early': 0    0.266511
#  Name: kda_early, dtype: float64,
#  'kda_mid': 0    0.411265
#  Name: kda_mid, dtype: float64,
# ...

# %%
james
# Out:
#      csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0  0.509677  292.354839  334.794624   0.182752         0.228005     40.032258
#
#    kill_participation  obj_dmg_share   dragons    barons  wards_cleared  \
# 0            0.505541       0.454272  0.433269  0.195341       0.396977
#
#    vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# 0                0.323983   0.266511  0.411265  0.263895    0.074019
#
#    teamfight_kills  skirmish_kills  wards_early  wards_mid  wards_late  \
# 0         0.442808         0.26987     0.279443   0.423369    0.227719
#
#                                        summoner_id  most_played_champ  \
# 0  JA9PzHteIJvObXbm_ltkED-zJ_cZjCrw-BObnVal_WIcT3Q                 60
#
#   most_played_role most_played_lane region  player_name
# 0             NONE           JUNGLE     na  Smurf Elise

# %%
result.to_json('./test.json')

# %%
x = result.to_dict(orient='split')

# %%
x.keys()
# Out:
# dict_keys(['index', 'columns', 'data'])

# %%
x['data']
# Out:
# [[0.5096774193548388,
#   292.3548387096775,
#   334.79462365591405,
#   0.18275162377753487,
#   0.22800530335859825,
#   40.032258064516135,
#   0.5055411320080421,
#   0.4542723865329299,
#   0.4332693292370711,
#   0.19534050179211476,
#   0.3969769909669905,
#   0.32398265379212016,
#   0.2665112579666937,
#   0.4112650323556716,
#   0.26389540083611235,
#   0.07401896192218771,
#   0.4428076702270251,
#   0.269870123902382,
#   0.2794429097870838,
#   0.42336926288995935,
#   0.2277193111274855,
#   'JA9PzHteIJvObXbm_ltkED-zJ_cZjCrw-BObnVal_WIcT3Q',
#   60,
#   'NONE',
#   'JUNGLE',
#   'na',
#   'Smurf Elise',
#   nan,
#   'Elise'],
#  [0.6189655172413792,
#   297.7637931034484,
#   346.7925287356321,
#   0.17065602086643367,
#   0.23530870354408445,
#   39.839080459770116,
#   0.5430419422637149,
#   0.41031226057328907,
#   0.4372263273125344,
#   0.20833333333333331,
#   0.3764472174262048,
#   0.3229547764842779,
#   0.2871340675767067,
#   0.39137944112650297,
# ...

# %%
for key, value in x.items():
    print(key)
    for v in value:
        print(value[v])
# Out:
# csd_10
# 0.5096774193548388
# 0.6189655172413792
# 0.7090909090909091
# 0.7868421052631579
# 0.661111111111111
# 1.3228571428571416
# 0.5989247311827957
# 1.6857142857142855
# 1.267080745341614
# 1.632692307692308
# gold_d_10
# 292.3548387096775
# 297.7637931034484
# 312.890909090909
# 304.88026315789466
# 308.52962962962965
# 285.9685714285715
# 303.92365591397856
# 287.75892857142856
# 305.0267080745344
# 297.70384615384614
# xpd_10
# 334.79462365591405
# 346.7925287356321
# 344.75454545454534
# 342.9052631578948
# 321.8666666666667
# 329.9285714285716
# 359.08602150537627
# 352.4830357142857
# 330.82360248447213
# 363.52019230769235
# dmg_share
# 0.18275162377753487
# 0.17065602086643367
# 0.2253610901758644
# 0.1885199209134445
# 0.1762466511661203
# 0.19128287574482186
# 0.17711357433636934
# 0.19192079058265812
# 0.18188014135363467
# 0.19534728078036706
# dmg_taken_share
# 0.22800530335859825
# 0.23530870354408445
# 0.2491533869550513
# 0.2582420078907119
# 0.2388082871803012
# ...

# %%
x = pd.read_csv('../../Capstone_app/data/role_models_final.csv')
x.shape
x.head()

x.drop(columns=['summoner_id','most_played_champ','most_played_role','most_played_lane','region','player_name','most_played_champ_name','op_gg','role']).shape
# Out:
# (6966, 21)

# %%
for key, value in x.items():
    print(key, value, '\n')
# Out:
# csd_10 {0: 0.5096774193548388, 154: 0.6189655172413792, 2258: 0.7090909090909091, 1583: 0.7868421052631579, 1870: 0.661111111111111, 225: 1.3228571428571416, 481: 0.5989247311827957, 346: 1.6857142857142855, 1139: 1.267080745341614, 6121: 1.632692307692308}
#
# gold_d_10 {0: 292.3548387096775, 154: 297.7637931034484, 2258: 312.890909090909, 1583: 304.88026315789466, 1870: 308.52962962962965, 225: 285.9685714285715, 481: 303.92365591397856, 346: 287.75892857142856, 1139: 305.0267080745344, 6121: 297.70384615384614}
#
# xpd_10 {0: 334.79462365591405, 154: 346.7925287356321, 2258: 344.75454545454534, 1583: 342.9052631578948, 1870: 321.8666666666667, 225: 329.9285714285716, 481: 359.08602150537627, 346: 352.4830357142857, 1139: 330.82360248447213, 6121: 363.52019230769235}
#
# ...

# %%
result = pd.concat([james,role_models.sort_values('jr_similarity')]).head(10)

# %%
pd.concat([james,role_models.iloc[[2815,2464,6714,6804,6922,6780],:]])
# Out:
#         csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  \
# 0     1.055435  204.533696  267.578261   0.130517         0.157633
# 2815  2.977778  219.190476  301.158730   0.139154         0.135513
# 2464  2.003150  217.700787  290.233071   0.142265         0.146133
# 6714  2.106250  227.421875  308.200000   0.144354         0.131747
# 6804  4.736842  341.830526  413.812632   0.283116         0.224012
# 6922  5.334286  287.857143  421.745714   0.231527         0.221611
# 6780  5.523077  306.166346  445.237500   0.252047         0.231000
#
#       vision_score  kill_participation  obj_dmg_share   dragons    barons  \
# 0        48.184783            0.496008       0.067509  0.396752  0.172101
# 2815     42.650794            0.510629       0.065101  0.386092  0.166667
# 2464     51.527559            0.525452       0.063397  0.368685  0.188320
# 6714     52.437500            0.497170       0.074393  0.433966  0.231771
# ...

# %%
champions_df.head()
# Out:
#    version       id  key     name                title  \
# 0  10.16.1   Aatrox  266   Aatrox     the Darkin Blade
# 1  10.16.1     Ahri  103     Ahri  the Nine-Tailed Fox
# 2  10.16.1    Akali   84    Akali   the Rogue Assassin
# 3  10.16.1  Alistar   12  Alistar         the Minotaur
# 4  10.16.1    Amumu   32    Amumu        the Sad Mummy
#
#                                                blurb  \
# 0  Once honored defenders of Shurima against the ...
# 1  Innately connected to the latent power of Rune...
# 2  Abandoning the Kinkou Order and her title of t...
# 3  Always a mighty warrior with a fearsome reputa...
# 4  Legend claims that Amumu is a lonely and melan...
#
#                                                 info  \
# 0  {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# 1  {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# 2  {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# 3  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# ...

# %%
champions_df.loc[0,'key'] == 266
# Out:
# True

# %%
champions_df = pd.read_csv('../data/champions_df.csv')
def champ_number_to_name(champ_number):

    return champions_df.loc[champions_df['key'] == int(champ_number),'name'].values[0]

t = result['most_played_champ'].map(champ_number_to_name)
result['most_played_champ_name'] = result['most_played_champ'].map(champ_number_to_name)

# %%
role_models['most_played_role'].value_counts()
# Out:
# SOLO           2818
# NONE           1439
# DUO_SUPPORT    1421
# DUO_CARRY      1284
# DUO               4
# Name: most_played_role, dtype: int64

# %%
role_models['most_played_lane'].value_counts()
# Out:
# BOTTOM    2720
# MIDDLE    1517
# JUNGLE    1444
# TOP       1281
# NONE         4
# Name: most_played_lane, dtype: int64

# %%
role_models[role_models['most_played_lane'] == 'NONE']
# Out:
#         csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  \
# 986   4.961290  289.964516  352.287097   0.212458         0.207698
# 4642  3.997222  326.644444  366.422222   0.232624         0.235687
# 6466  3.754902  267.366667  361.915686   0.182432         0.214658
# 6701  3.851515  262.963636  358.633333   0.158843         0.200285
#
#       vision_score  kill_participation  obj_dmg_share   dragons    barons  \
# 986      17.451613            0.438741       0.200735  0.333180  0.107527
# 4642     14.888889            0.505962       0.208701  0.365741  0.166667
# 6466     16.098039            0.425361       0.206047  0.324627  0.178105
# 6701     27.454545            0.403960       0.219199  0.366595  0.138384
#
#       wards_cleared  vision_wards_purchased  kda_early   kda_mid  kda_late  \
# 986        0.227332                0.176760   0.357534  0.410984  0.158106
# 4642       0.241949                0.119929   0.365815  0.393061  0.173403
# ...

# %%
james.loc[0,'most_played_champ']
# Out:
# 60

# %%
role_models[role_models['most_played_champ'] == james.loc[0,'most_played_champ']]
# Out:
#         csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  \
# 154   0.618966  297.763793  346.792529   0.170656         0.235309
# 481   0.598925  303.923656  359.086022   0.177114         0.237169
# 1039  0.701190  305.878571  332.672222   0.195303         0.228203
# 1256  0.958197  328.804098  363.477049   0.222726         0.248216
# 1313  0.770000  303.352727  334.687273   0.189283         0.223203
# 1332  0.552336  340.145794  366.397196   0.250388         0.274068
# 1364  0.920588  340.523529  361.086275   0.233752         0.252075
# 1427  5.190625  303.429167  414.443750   0.223196         0.220534
# 1982  2.197872  298.361702  346.638298   0.184736         0.231285
# 2193  0.641667  294.930556  306.752778   0.165749         0.233018
# 2339  0.688889  318.391503  373.816013   0.210157         0.239343
# 2588  3.372277  289.726733  313.160396   0.214572         0.227411
# 2736  2.427273  300.306494  349.244156   0.190308         0.237479
# ...

# %%
def roles_to_single_value(role, lane):
    if lane == 'TOP':
        return 'Top'
    elif lane == 'MIDDLE':
        return 'Mid'
    elif lane == 'JUNGLE':
        return 'Jungle'
    elif role == 'DUO_CARRY':
        return 'Bot Carry'
    elif role =='DUO_SUPPORT':
        return 'Support'
    
[roles_to_single_value(role, lane) for role, lane in zip(result['most_played_role'], result['most_played_lane'])]
# Out:
# ['Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle',
#  'Jungle']

# %%
result.loc[0,'most_played_champ'] == '60'
# Out:
# False

# %%
def to_op_gg(name, region):
    from urllib.parse import quote
    name = quote(name)

    if region == 'kr':
        base_url = 'https://www.op.gg/summoner/userName='
    elif region == 'eun':
        base_url = 'https://eune.op.gg/summoner/userName='
    elif region == 'la1':
        base_url = 'https://lan.op.gg/summoner/userName='
    elif region == 'la2':
        base_url = 'https://las.op.gg/summoner/userName='
    else:
        base_url = f'https://{region}.op.gg/summoner/userName='
    
    return f'{base_url}{name}'

x = [to_op_gg(name, region) for name, region in zip(result['player_name'], result['region'])]
x
# Out:
# ['https://na.op.gg/summoner/userName=Smurf%20Elise',
#  'https://na.op.gg/summoner/userName=1936%201948',
#  'https://br.op.gg/summoner/userName=tottilt',
#  'https://br.op.gg/summoner/userName=oia%20o%20alek',
#  'https://br.op.gg/summoner/userName=PERLY%20FANBOY',
#  'https://na.op.gg/summoner/userName=WX%20nadaixie',
#  'https://na.op.gg/summoner/userName=RexRequired',
#  'https://na.op.gg/summoner/userName=Sybr',
#  'https://br.op.gg/summoner/userName=%20apenas%20o%20jacoba',
#  'https://tr.op.gg/summoner/userName=Kir%C3%A4']

# %%
train, test = train_test_split(X, test_size = 5, random_state = 42)

# %%
role_models.iloc[[3693,2978,673,4348,1070,6818,2308],:]
# Out:
#            game_id  player_id  champ_played    csd_10   gold_d_10      xpd_10  \
# 3693  4.733033e+09   4.650943    115.320755  6.455660  296.501887  322.509434
# 2978  2.560408e+09   4.891304    141.739130  7.113043  286.126087  424.178261
# 673   3.503192e+09   4.471698    131.037736  5.730189  262.564151  416.724528
# 4348  4.761424e+09   5.114286    182.342857  6.874286  308.937143  321.742857
# 1070  2.018735e+09   5.138095    202.528571  6.968095  317.098571  435.309524
# 6818  3.177313e+08   4.145631    159.533981  5.380583  268.275728  406.858252
# 2308  2.015803e+09   4.709677    315.741935  0.819355  200.341935  276.232258
#
#       dmg_share  dmg_taken_share  vision_score  kill_participation  \
# 3693   0.122514         0.090845     20.292453            0.460203
# 2978   0.105860         0.092837     16.456522            0.438486
# 673    0.107101         0.104642     19.660377            0.385950
# 4348   0.117411         0.084436     11.971429            0.421880
# ...

# %%
test
# Out:
#         csd_10   gold_d_10      xpd_10  dmg_share  dmg_taken_share  \
# 4017  6.621667  314.736667  436.860000   0.124402         0.123255
# 2577  6.756863  289.283333  436.761765   0.096579         0.107590
# 3693  6.455660  296.501887  322.509434   0.122514         0.090845
# 6574  6.182500  293.430000  446.887500   0.105359         0.118040
# 7566  1.082222  187.591111  270.742222   0.036423         0.053795
#
#       vision_score  kill_participation  obj_dmg_share   dragons    barons  \
# 4017     24.583333            0.448012       0.090452  2.216667  0.516667
# 2577     17.127451            0.410338       0.089410  1.843137  0.539216
# 3693     20.292453            0.460203       0.098105  1.811321  0.415094
# 6574     20.350000            0.390394       0.067681  1.700000  0.350000
# 7566     41.288889            0.555699       0.016884  1.822222  0.355556
#
#       ...  vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# ...

# %%
pd.DataFrame(ss.transform(test), columns=X.columns)
# Out:
#      csd_10  gold_d_10    xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0  0.918673   0.890190  1.316869   1.034173         1.065918     -0.317609
# 1  0.974520   0.220366  1.315181  -0.124956         0.358408     -0.924423
# 2  0.850099   0.410328 -0.648454   0.955492        -0.397872     -0.666832
# 3  0.737262   0.329489  1.489210   0.240835         0.830381     -0.662149
# 4 -1.369560  -2.455740 -1.538167  -2.631008        -2.071257      1.042009
#
#    kill_participation  obj_dmg_share   dragons    barons  ...  \
# 0           -0.486445      -0.146474  1.781439  0.874901  ...
# 1           -1.183002      -0.163276  0.028556  1.132998  ...
# 2           -0.261042      -0.023056 -0.120752 -0.287704  ...
# 3           -1.551749      -0.513687 -0.643153 -1.032779  ...
# 4            1.504610      -1.332893 -0.069594 -0.969190  ...
#
#    vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# ...

# %%
test_cases
# Out:
#      csd_10  gold_d_10    xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0  0.918673   0.890190  1.316869   1.034173         1.065918     -0.317609
# 1  0.974520   0.220366  1.315181  -0.124956         0.358408     -0.924423
# 2  0.850099   0.410328 -0.648454   0.955492        -0.397872     -0.666832
# 3  0.737262   0.329489  1.489210   0.240835         0.830381     -0.662149
# 4 -1.369560  -2.455740 -1.538167  -2.631008        -2.071257      1.042009
#
#    kill_participation  obj_dmg_share   dragons    barons  ...  \
# 0           -0.486445      -0.146474  1.781439  0.874901  ...
# 1           -1.183002      -0.163276  0.028556  1.132998  ...
# 2           -0.261042      -0.023056 -0.120752 -0.287704  ...
# 3           -1.551749      -0.513687 -0.643153 -1.032779  ...
# 4            1.504610      -1.332893 -0.069594 -0.969190  ...
#
#    vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# ...

# %%
ss = StandardScaler()
X_sc = ss.fit_transform(X)

valid_cases, test_cases = train_test_split(X_sc, test_size = 5, random_state = 42)

# %%
valid_cases = pd.DataFrame(valid_cases, columns=X.columns)

# %%
test_cases = pd.DataFrame(test_cases, columns=X.columns)

# %%
X.dtypes

# %%
type(valid_cases)
# Out:
# numpy.ndarray

# %%
type(test_cases)
# Out:
# numpy.ndarray

# %%
test_cases.shape[1]
# Out:
# 21

# %%
np.linalg.norm()

# %%
test_cases
# Out:
#      csd_10  gold_d_10    xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0  0.918673   0.890190  1.316869   1.034173         1.065918     -0.317609
# 1  0.974520   0.220366  1.315181  -0.124956         0.358408     -0.924423
# 2  0.850099   0.410328 -0.648454   0.955492        -0.397872     -0.666832
# 3  0.737262   0.329489  1.489210   0.240835         0.830381     -0.662149
# 4 -1.369560  -2.455740 -1.538167  -2.631008        -2.071257      1.042009
#
#    kill_participation  obj_dmg_share   dragons    barons  ...  \
# 0           -0.486445      -0.146474  1.781439  0.874901  ...
# 1           -1.183002      -0.163276  0.028556  1.132998  ...
# 2           -0.261042      -0.023056 -0.120752 -0.287704  ...
# 3           -1.551749      -0.513687 -0.643153 -1.032779  ...
# 4            1.504610      -1.332893 -0.069594 -0.969190  ...
#
#    vision_wards_purchased  kda_early   kda_mid  kda_late  solo_kills  \
# ...

# %%
norm_dfs[2].sort_values()
# Out:
# 2978     1.212196
# 673      1.266229
# 4348     1.302965
# 3396     1.335405
# 3208     1.361416
#           ...
# 4463    24.904729
# 3476    26.916618
# 1070    31.657015
# 6818    36.229679
# 2308    41.113585
# Length: 7994, dtype: float64

# %%
norm_dfs[2].idxmin()
# Out:
# 5688

# %%
np.linalg.norm()

# %%
diff_dfs = []
norm_dfs = []

for i in range(0,test_cases.shape[0]):
    diff_dfs.append(valid_cases - test_cases.iloc[i,:])
    norm_dfs.append(diff_dfs[i].apply(np.linalg.norm, axis=1))
    print(valid_cases.loc[norm_dfs[i].idxmin()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-530377d1bae6> in <module>
#       3
#       4 for i in range(0,test_cases.shape[0]):
# ----> 5     diff_dfs.append(valid_cases - test_cases.iloc[i,:])
#       6     norm_dfs.append(diff_dfs[i].apply(np.linalg.norm,ord=2, axis=1))
#       7     print(valid_cases.loc[norm_dfs[i].idxmin()])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
norm_dfs[0]
# Out:
# array([4.03954273, 7.7174204 , 6.58072214, ..., 5.18008739, 6.20933756,
#        7.12207002])

# %%
pd.DataFrame(valid_cases, columns=X.columns)
# Out:
#         csd_10  gold_d_10    xpd_10  dmg_share  dmg_taken_share  vision_score  \
# 0     0.462292   0.061692 -0.768073   0.273761        -0.430092      0.589287
# 1    -1.247974  -2.253245 -1.436497  -1.321101        -1.375380      2.198612
# 2    -1.290471   1.606506  0.314942   0.993259         1.265736     -0.307495
# 3     0.568744   0.024202  0.825045  -0.212998         0.297782     -0.495305
# 4     0.406006  -0.332464  0.801235  -0.041788         0.915589     -1.112583
# ...        ...        ...       ...        ...              ...           ...
# 7989  0.975649   0.759640  1.235459   0.543576         0.598252     -0.857519
# 7990 -1.449765   0.968054 -0.422571  -0.163144         1.326722     -0.024960
# 7991  1.246885   0.708144  1.037040   1.356138         0.091898     -0.527860
# 7992 -0.459342  -1.226060 -1.090563  -0.999295        -1.119834      1.030124
# 7993 -1.420320   1.272798  0.243664   1.288486         0.953298     -0.829261
#
# ...
